# %%
path = '../data/weather_data.json'
import pandas as pd 
import json 
from pathlib import Path
import os

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
with open(path) as f: 
    data = json.load(f)

df = pd.json_normalize(data)
df.head()
# Out:
#                                                                      weather  \
# 0  [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}]
#
#        base  visibility          dt  timezone       id      name  cod  \
# 0  stations       10000  1771079151    -10800  3457952  Manhuaçu  200
#
#    coord.lon  coord.lat  main.temp  main.feels_like  main.temp_min  \
# 0   -42.0336   -20.2581      26.28            26.28          26.28
#
#    main.temp_max  main.pressure  main.humidity  main.sea_level  \
# 0          26.28           1018             61            1018
#
#    main.grnd_level  wind.speed  wind.deg  wind.gust  clouds.all sys.country  \
# 0              923        0.92        14       1.12           0          BR
#
#    sys.sunrise  sys.sunset
# 0   1771058353  1771104338

# %%
data.info()
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 data.info()
#       2 df.columns
#
# NameError: name 'data' is not defined
